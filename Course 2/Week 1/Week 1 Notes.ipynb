# %% [markdown]
# # <span style="font-family:cursive;text-align:center">Neural Networks :</span>

# %% [markdown]
# ## <span style="font-family:cursive;text-align:center">Neural Networks Intuition:</span>

# %% [markdown]
# Neural Networks was created to try to Mimic how Human Brain works
# Used in 1980s and 90s ,Resurgence from 2005
#
# Applications : Sppech 👉 Images 👉 text (NLP) 👉 etc...
#
# Neural Networs today have nothing to do with brain😅
#
# The amount of digital data have exploded and traditional AI algos did not improve Performance over data,This is where Neural Network comes in!

# %% [markdown]
# * `Input` is passed to the `neuron` which in turns predicts the `Output`
# * Group of neurons are stacked to form a layer
# * A layer is a grouping of neurons which takes as input the same or similar features, and that in turn outputs a few numbers together.
# * layer of the neural network uses those input numbers to compute the new numbers also called activation values
# * Every neuron in the layer will have access to values in the previous layers

# %% [markdown]
# ## <span style="font-family:cursive;text-align:center">Neural network model:</span>

# %% [markdown]
# `Neural Netork Layer`
#
# The first layer of a neural net is called the input layer, followed by hidden layers, then finally the output layer. Information flows through a neural network in two ways. When it’s learning (being trained) or operating normally (after being trained), patterns of information are fed into the network via the input units, which trigger the layers of hidden units, and these in turn arrive at the output units1.
#
# The neural network works by propagating forward inputs, weights, and biases. However, it’s the reverse process of backpropagation where the network actually learns by determining the exact changes to make to weights and biases to produce an accurate results.

# %% [markdown]
# ## <span style="font-family:cursive;text-align:center">TensorFlow implementation:</span>

# %% [markdown]
# `Data in Tensorflow`
#
# * There are few inconsistencies between TF & numpy on how data is represented like storing of vectors and Matrices.
# * Since tensorflow was designed to handle large dataset & computationally effective it was designed so!
# * Tensor is a data type created to carry out computationally effective matrix,moreover like a matrix
# * when numpy array is passed to tf its convereted to Tensor, .numpy() method will convert tensor to numpy array

# %% [markdown]
# ## <span style="font-family:cursive;text-align:center">Vectorization:</span>

# %% [markdown]
# `How Neural Networks are Implemented Efficiently`
#
# * np.matmul method can be used to write short and efficient code
